# %% [markdown]
# # Lab 1
#
# #### Topics covered:
# 1. Intro to packages
# 2. Data Science Life Cycle
# 3. Data Manuplation using Pandas
# 4. Data Structures
# 5. Visualizations
# 6. Intro to APIs
# 7. Regex
# 8. Intro to NLP tasks!

# %%
# load the packages we will use for the remainder of the lab.
import pandas as pd 
import numpy as np 
import regex as re

# %% [markdown]
# Understanding packages in python:
# The above cell imports certain packages which allow particular functionalities.Important documentation for the packages (These are for reference only):
#
# Numpy Basics: https://numpy.org/doc/stable/user/absolute_beginners.html
#
# Data 8 Numpy manuplation guide: http://data8.org/su22/python-reference.html
#
# Pandas: https://pandas.pydata.org/docs/user_guide/index.html
#
# Pandas Dataframe manuplation: https://https://pandas.pydata.org/docs/reference/frame.html
#
# Matplotlib: https://matplotlib.org/stable/tutorials/introductory/usage.html
#
# The following video provides an insight into the data science lifecycle, aka steps taken to analyze data and produce results.

# %%
## Do not edit this code block
# !pip install pytube
from IPython.display import YouTubeVideo
YouTubeVideo('5I2bYqeFQy4')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytube
#   Downloading pytube-12.1.0-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 1.3 MB/s
# Installing collected packages: pytube
# Successfully installed pytube-12.1.0

# %% [markdown]
# ### **Data Structures in Python**

# %% [markdown]
# #### String

# %% [markdown]
# In Python, a string is a sequence of Unicode characters. Strings can be created by enclosing characters inside a single quote or double-quotes.

# %%
#All 4 strings are the same 
String = "Hello World" 
String = 'Hello World' 
String = """Hello World""" 
String = "Hello" + " " + "World"
print(String)
# Out:
# Hello World

# %%
first_letter = String[0] #Indexs start at 0 
last_letter = String[-1] #Indexs into the last character 
for letter in String: #Prints each letter in our String 
  print(letter)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %% [markdown]
# #### List
# Python **lists** are indexable data structures which can hold different kinds of data! They may look something like the following:
#
# ```
# friends = ['Rachel', 'Chandler', 'Joey', 'Monica', 'Ross', 'Phoebe']
#
# odd_nums = [1, 3, 5, 7, 9]
# ```
#
# To retrieve an element in a list, you would need to index into this list, starting with an index value of 0. For example, if you wanted to return the second integer in *odd_nums*, you would do the following:

# %%
odd_nums = [1, 3, 5, 7, 9]
odd_nums[1]
# Out:
# 3

# %% [markdown]
# **Question 1: Replace the ellipses and try to return 'Joey' from the `friends` list!**

# %%
friends = ['Rachel', 'Chandler', 'Joey', 'Monica', 'Ross', 'Phoebe']
...

# %% [markdown]
# **Array** is another data structure we commonly use in python. It works similar as **list**, as shown below.

# %%
array = np.array(["Appeals" ,"Supreme", "Court" , "Justice"])
#Prints the first and second item of the array 
print(array[0])
print(array[1])
# Out:
# Appeals
# Supreme

# %% [markdown]
# #### Dictionary
# The **dictionary** data structure is useful for holding pairs of data. Dictionaries look like
#
# ```
# Dictionary = { key : value , key : value , key : value}
# ```
#
# You might notice that unlike lists that use `[]`, dictionaries use `{}` followed by a key : value pair. Each key-value pair is seperated by a comma.
#
# For example if we wanted to create dictonary called states where the key is the name of the state and the value is the state abbrevation.

# %%
states = {"California" : 'CA',
          "Idaho" : 'ID',
          "Nevada" : 'NV'}
states
# Out:
# {'California': 'CA', 'Idaho': 'ID', 'Nevada': 'NV'}

# %% [markdown]
# You can access the abbreviations by indexing into the dictionary with brackets and the key value. For example, if you want to return `VALUE` associated with `KEY`, you would do the following:
#
# ```
# example_dict[KEY]
# ```
#
# This would return `VALUE`.

# %% [markdown]
# **Question 2: How would you return the abbreviation for Nevada using the states dictionary above? Assign *result* to this expression.**

# %%
# Using the states dictionary above, assign result to 'ID' by replacing the ellipses
result = states ["Idaho"]
result
# Out:
# 'ID'

# %% [markdown]
# ### **Loading and Inspecting Data with Pandas**
# First, we will use the pandas package to read in two different types of file formats csv and json. The functions read_csv and read_json takes in one argument, the file path of the file you wish to read in.

# %%
df = pd.read_csv("/content/sample_data/california_housing_train.csv")
df2 = pd.read_json("/content/sample_data/anscombe.json")

# %% [markdown]
# Now that we have loaded in our DataFrames we want see our new table. Here are a few useful methods to see our table. We can use the `head()` function to see the first 5 rows of our table. Alternatively we can use the `tail()` to see the last 5 rows of our table. The shape method returns a tuple where the first item is the number of rows and the second is the number columns in the table.
#
# ```
# df.head()
# df.tail()
# df.shape
# ```
#
# Now that we know what are table looks like and the shape of it, we can use the `describe()` function to see basic summary statistics from our table.
#
# ```
# df.describe()
# ```

# %%
# Show first 5 rows of our data
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
# Show last 5 rows of our data
df.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
rows , columns = df.shape[0] , df.shape[1]
print("The number of rows is: " + str(rows), "  The number of columns is: " + str(columns))
# Out:
# The number of rows is: 17000   The number of columns is: 9

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# 25%        297.000000    790.000000    282.000000       2.566375
# 50%        434.000000   1167.000000    409.000000       3.544600
# 75%        648.250000   1721.000000    605.250000       4.767000
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        17000.000000
# mean        207300.912353
# std         115983.764387
# min          14999.000000
# 25%         119400.000000
# 50%         180400.000000
# 75%         265000.000000
# max         500001.000000

# %% [markdown]
# ### **Manipulating the DataFrame**
# Next we will cover dropping unwanted values and duplicate rows using `dropna()` and `drop_duplicates()` respectively. Both of these functions return a new DataFrame without changing the original by default. In order to store the new table you will have to assign it to a variable. This is generally the default behavior for most Pandas functions

# %%
new_df = df.dropna()
new_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
print('The number of rows after droping N/A values is',new_df.shape[0])
# Out:
# The number of rows after droping N/A values is 17000

# %%
new_df = new_df.drop_duplicates()
new_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
print('The number of rows after droping duplicate values is',new_df.shape[0])
# Out:
# The number of rows after droping duplicate values is 17000

# %% [markdown]
# Hooray! Seems like our data doesn't have any N/A or duplicate values. Then we can proceed to explore more of our dataset.

# %% [markdown]
# One way to manipulate DataFrame tables is to use `df['column name']` to return one column of the table. In the example below we look at the housing_median_age column and use `value_counts()` to see how many times each unique value appears. Similarly, you can also apply other functions to columns.
#
# Adding new columns also uses this `["column name"]` syntax. You can specify `df["column name"]` and set it equal to the data you want to add. For example if you wanted to add a column of names with all upper case letters.
# ```
# df["upper_case_names"] = df["names"].str.upper()
# ```

# %%
df['housing_median_age'].value_counts()
# Out:
# 52.0    1052
# 36.0     715
# 35.0     692
# 16.0     635
# 17.0     576
# 34.0     567
# 33.0     513
# 26.0     503
# 18.0     478
# 25.0     461
# 32.0     458
# 37.0     437
# 15.0     416
# 19.0     412
# 28.0     400
# 27.0     397
# 24.0     389
# 31.0     384
# 30.0     384
# 20.0     383
# 23.0     382
# 29.0     374
# 21.0     373
# 14.0     347
# 22.0     323
# 38.0     318
# 42.0     308
# 39.0     302
# 44.0     296
# 43.0     286
# 13.0     249
# 40.0     249
# 45.0     235
# 41.0     232
# 10.0     226
# 11.0     208
# 5.0      199
# 46.0     196
# 12.0     192
# 8.0      178
# 47.0     175
# 9.0      172
# 4.0      161
# 7.0      151
# 48.0     135
# 6.0      129
# 50.0     112
# 49.0     111
# 2.0       49
# 3.0       46
# 51.0      32
# 1.0        2
# Name: housing_median_age, dtype: int64

# %% [markdown]
# **Question 3: How would you add a column for log population? Replace ... with your answer. (Hint use np.log())**

# %%
df["log_population"] = ...
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value  \
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0
#
#       log_population
# 0           Ellipsis
# 1           Ellipsis
# 2           Ellipsis
# 3           Ellipsis
# 4           Ellipsis
# ...              ...
# 16995       Ellipsis
# 16996       Ellipsis
# 16997       Ellipsis
# 16998       Ellipsis
# 16999       Ellipsis
#
# [17000 rows x 10 columns]

# %% [markdown]
# You can also use
#
# ```
# df[df["column"] == Condition]
# ```
# to only keep rows where a certain condition is met.

# %%
# Example: Only keep rows where population is above the average
df[df["population"] > np.mean(df["population"])]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6        -114.58     33.61                25.0       2907.0           680.0
# 8        -114.59     33.61                34.0       4789.0          1175.0
# 10       -114.60     33.62                16.0       3741.0           801.0
# 24       -115.22     33.54                18.0       1706.0           397.0
# 38       -115.48     32.68                15.0       3414.0           666.0
# ...          ...       ...                 ...          ...             ...
# 16983    -124.19     41.78                15.0       3140.0           714.0
# 16986    -124.19     40.73                21.0       5694.0          1056.0
# 16987    -124.21     41.77                17.0       3461.0           722.0
# 16988    -124.21     41.75                20.0       3810.0           787.0
# 16990    -124.22     41.73                28.0       3003.0           699.0
#
#        population  households  median_income  median_house_value  \
# 6          1841.0       633.0         2.6768             82400.0
# 8          3134.0      1056.0         2.1782             58400.0
# 10         2434.0       824.0         2.6797             86500.0
# 24         3424.0       283.0         1.6250             53500.0
# 38         2097.0       622.0         2.3319             91200.0
# ...           ...         ...            ...                 ...
# 16983      1645.0       640.0         1.6654             74600.0
# 16986      2907.0       972.0         3.5363             90100.0
# 16987      1947.0       647.0         2.5795             68400.0
# 16988      1993.0       721.0         2.0074             66900.0
# 16990      1530.0       653.0         1.7038             78300.0
#
#       log_population
# 6           Ellipsis
# 8           Ellipsis
# 10          Ellipsis
# 24          Ellipsis
# 38          Ellipsis
# ...              ...
# 16983       Ellipsis
# 16986       Ellipsis
# 16987       Ellipsis
# 16988       Ellipsis
# 16990       Ellipsis
#
# [6138 rows x 10 columns]

# %% [markdown]
# If you want to select more than one column at a time and/or a certain number of rows you can use
#
# ```
# df.loc(: , ['column_name' , 'column_name'])
# ```
# where the first argument is the index you want and the second argument is the list of columns you want. The : character is shorthand for all. This example gives you all the rows for the two columns.

# %% [markdown]
# ## Plotting with DataFrames
# ## Histograms
# Histograms are a nifty way to display quantitative information. The x-axis is typically a quantitative variable of interest, and the y-axis is generally a frequency. Plot a histogram of the losses, and then experiment with the bin sizes.italicized text

# %%
df.hist("median_house_value",grid = False)

# Try uncommenting the following lines and see the different results. What does this tell you about the parameters used?

#df.hist("median_house_value",bins = range(0,500000,1000) ,grid = False)
#df.hist("median_house_value" ,grid = False)
#df.hist("median_house_value",grid = True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4dae62fc90>]],
#       dtype=object)

# %% [markdown]
# ## Scatter Plots
# Scatter plots are generally used to relate two variables to one another. They can be useful when trying to infer relationships between variables, visualize simple regressions, and get a general sense of the "spread" of your data.

# %%
# Median house value vs Median income. Do you spot a correlation?
df.plot.scatter(x = "median_income", y = "median_house_value")

# %% [markdown]
# ## Part 2: Introduction to API

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/MyDrive/ls-190colab/cap-examples
# %ls
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/ls-190colab/cap-examples
# api_text_search/          get_judges/             python_wrapper/
# api_to_csv/               introduction/           README.md
# api_tutorial_downloader/  labelling_summarizing/  requirements.in
# bulk_exploration/         LICENSE                 requirements.txt
# bulk_extract/             logs.log                sample_text.txt
# config/                   map_courts/             settings.py
# d2v-vectors.pkl           m.model                 tests/
# data/                     m.vocab                 utils.py
# fabfile.py                ngrams/                 w2v-vectors.pkl
# full_text_search/         __pycache__/            X_tfidf.pkl

# %%
#! git clone https://github.com/harvard-lil/cap-examples.git

# %%
#%cd ./cap-examples

# %%
#!pip install -r requirements.txt

# %%
#!pip install fabric3==1.14.post1
#!fab setup

# %%
import os
import sys
sys.path.append('..')

import lzma
import json

from config import settings_base as settings
import utils

# %%
# Get Case Data for Illinois
compressed_file = utils.get_and_extract_from_bulk(jurisdiction="Illinois", data_format="json")

# %%
# Assume we are dealing with json data (if data_format is changed to xml or
# change this cell's os.path.join line)
if not compressed_file.endswith('.xz'):
  compressed_file = os.path.join(compressed_file, "data", "data.jsonl.xz")

# %%
cases = []
print("File path:", compressed_file)
with lzma.open(compressed_file) as infile:
    for line in infile:
        record = json.loads(str(line, 'utf-8'))
        cases.append(record)

print("Case count: %s" % len(cases))
# Out:
# File path: /content/gdrive/MyDrive/ls-190colab/cap-examples/config/../data/Illinois-20200302-text/data/data.jsonl.xz
# Case count: 183146

# %%
df = pd.DataFrame(cases)
df.head()
# Out:
#        id                                      url  \
# 0  544894  https://api.capapi.org/v1/cases/544894/
# 1  544872  https://api.capapi.org/v1/cases/544872/
# 2  544855  https://api.capapi.org/v1/cases/544855/
# 3  544890  https://api.capapi.org/v1/cases/544890/
# 4  544916  https://api.capapi.org/v1/cases/544916/
#
#                                                 name  \
# 0  In re MARRIAGE OF LARRY LAPPE and LYNN LAPPE, ...
# 1  THE PEOPLE OF THE STATE OF ILLINOIS, Appellee,...
# 2  THE PEOPLE OF THE STATE OF ILLINOIS, Appellee,...
# 3  STAN LIEBER, Appellee, v. THE BOARD OF TRUSTEE...
# 4  FIREMAN’S FUND INSURANCE COMPANY, as Subrogee ...
#
#                                    name_abbreviation decision_date  \
# 0                            In re Marriage of Lappe    1997-05-01
# 1                                  People v. Pulliam    1997-04-17
# 2                                    People v. Smith    1997-03-20
# 3  Lieber v. Board of Trustees of Southern Illino...    1997-05-01
# 4      Fireman’s Fund Insurance v. SEC Donohue, Inc.    1997-04-17
#
#   docket_number first_page last_page  \
# 0     No. 81605        414       443
# 1     No. 78406        261       289
# 2     No. 77695        217       261
# 3     No. 81220        401       414
# 4     No. 81439        160       170
#
#                                            citations  \
# 0  [{'type': 'official', 'cite': '176 Ill. 2d 414'}]
# 1  [{'type': 'official', 'cite': '176 Ill. 2d 261'}]
# 2  [{'type': 'official', 'cite': '176 Ill. 2d 217'}]
# 3  [{'type': 'official', 'cite': '176 Ill. 2d 401'}]
# 4  [{'type': 'official', 'cite': '176 Ill. 2d 160'}]
#
#                                               volume  \
# 0  {'url': 'https://api.capapi.org/v1/volumes/320...
# 1  {'url': 'https://api.capapi.org/v1/volumes/320...
# 2  {'url': 'https://api.capapi.org/v1/volumes/320...
# 3  {'url': 'https://api.capapi.org/v1/volumes/320...
# 4  {'url': 'https://api.capapi.org/v1/volumes/320...
#
#                                             reporter  \
# 0  {'url': 'https://api.capapi.org/v1/reporters/5...
# 1  {'url': 'https://api.capapi.org/v1/reporters/5...
# 2  {'url': 'https://api.capapi.org/v1/reporters/5...
# 3  {'url': 'https://api.capapi.org/v1/reporters/5...
# 4  {'url': 'https://api.capapi.org/v1/reporters/5...
#
#                                                court  \
# 0  {'url': 'https://api.capapi.org/v1/courts/ill/...
# 1  {'url': 'https://api.capapi.org/v1/courts/ill/...
# 2  {'url': 'https://api.capapi.org/v1/courts/ill/...
# 3  {'url': 'https://api.capapi.org/v1/courts/ill/...
# 4  {'url': 'https://api.capapi.org/v1/courts/ill/...
#
#                                         jurisdiction  \
# 0  {'name': 'Ill.', 'name_long': 'Illinois', 'whi...
# 1  {'name': 'Ill.', 'name_long': 'Illinois', 'whi...
# 2  {'name': 'Ill.', 'name_long': 'Illinois', 'whi...
# 3  {'name': 'Ill.', 'name_long': 'Illinois', 'whi...
# 4  {'name': 'Ill.', 'name_long': 'Illinois', 'whi...
#
#                               frontend_url preview  \
# 0  https://cite.capapi.org/ill-2d/176/414/      []
# 1  https://cite.capapi.org/ill-2d/176/261/      []
# 2  https://cite.capapi.org/ill-2d/176/217/      []
# 3  https://cite.capapi.org/ill-2d/176/401/      []
# 4  https://cite.capapi.org/ill-2d/176/160/      []
#
#                                             casebody
# 0  {'data': {'judges': [], 'attorneys': ['James E...
# 1  {'data': {'judges': [], 'attorneys': ['Charles...
# 2  {'data': {'judges': [], 'attorneys': ['Rita A....
# 3  {'data': {'judges': [], 'attorneys': ['Michael...
# 4  {'data': {'judges': [], 'attorneys': ['Mark A....

# %% [markdown]
# ## Part 3: Introduction to API Tasks

# %% [markdown]
# ### **Spacy**

# %% [markdown]
# **spaCy** is an open-source NLP library which we'll be using to analyze features about textual data.

# %%
# Just run this cell

import spacy

text = "Today, I had a great time visiting Disneyland!"

# Configures pipeline for language processing
nlp = spacy.load("en_core_web_sm")

# Creates a pipeline for the string associated with variable "text"
pipe = nlp(text)

for token in pipe:
  print(token)
# Out:
# Today
# ,
# I
# had
# a
# great
# time
# visiting
# Disneyland
# !

# %% [markdown]
# Python's `split()` function is similar, but you'll notice that it's not so easy to separate words from punctuation, as compared to spaCy's tokenization.

# %%
# Just run this cell
text.split(' ')
# Out:
# ['Today,', 'I', 'had', 'a', 'great', 'time', 'visiting', 'Disneyland!']

# %% [markdown]
# **spaCy** is great because it's easy to retrieve various elements about the tokens within your text.
#
# For example, say with every token, you wanted to know the **part-of-speech**.

# %%
token_pos_pairs = []

for token in pipe:
  token_pos_pairs.append([token, token.pos_])

token_pos_pairs
# Out:
# [[Today, 'NOUN'],
#  [,, 'PUNCT'],
#  [I, 'PRON'],
#  [had, 'VERB'],
#  [a, 'DET'],
#  [great, 'ADJ'],
#  [time, 'NOUN'],
#  [visiting, 'VERB'],
#  [Disneyland, 'PROPN'],
#  [!, 'PUNCT']]

# %% [markdown]
# The "lemma" of a word can be considered its base form. For example, *eating*, *ate*, and *eat* all have the same lemma: *eat*.

# %% [markdown]
# **Question 5: Using the for loop above as inspiration, create a list `token_lemma_pairs`. This list will be the same shape as token_pos_pairs, but contain the lemma rather than part-of-speech.**

# %%
token_lemma_pairs = []

for token in pipe:
  ...

# The shape of token_lemma_pairs should match token_pos_pairs in the last coding cell
token_lemma_pairs
# Out:
# []

# %% [markdown]
# Let's say now, we want to create a dictionary with the keys being terms within a text, and values being the number of times the terms are present. In this case, tokenization with spacy can help!

# %%
text = "Hey, what'd you think about the new move?"
nlp = spacy.load("en_core_web_sm")
pipe = nlp(text).to_array('LANG')
pipe
# Out:
# array([14626626061804382878, 14626626061804382878, 14626626061804382878,
#        14626626061804382878, 14626626061804382878, 14626626061804382878,
#        14626626061804382878, 14626626061804382878, 14626626061804382878,
#        14626626061804382878, 14626626061804382878], dtype=uint64)

# %%
# Replace the 4 ellipses in the for-loop

# word_counts is a dictionary with tokens as the keys and counts as the values
word_counts = {}

# Creates a pipeline of tokens for our text
text = "hi hi hi hi hi hey hello hey" #REPLACE WITH A FILE!!!! This is just a test
nlp = spacy.load("en_core_web_sm")
pipe = nlp(text)

tokens = []

for token in pipe:
  tokens.append(str(token))

# word_counts[KEY] accesses a VALUE (count) associated with a KEY (token/word)
for token in tokens:
  # If the word already exists in the dictionary, what should you do to its count? 
  if token in word_counts:
    word_counts[token] += 1
  # What if it doesn't exist?
  else:
    word_counts[token] = 1

word_counts
# Out:
# {'hi': 5, 'hey': 2, 'hello': 1}

# %% [markdown]
# ### **Regex**

# %% [markdown]
# **Sets, Quantifiers, and Special Characters**
#
# Regex (regular expressions) is a very powerful tool to find patterns in text. One of the best ways to learn Regex is by using Regex 101 to practice matching words in a body of text.
#
# [Regex101](https://regex101.com/)
#
# [Regex Reference Sheet](http://www.rexegg.com/regex-quickstart.html#ref)
#
# For example, say we had a text and we wanted to find every instance of a word within that text.

# %%
# Just run this cell
import regex as re
text = "Samuel and I went down to the river yesterday! Samuel isn't a very good swimmer, though. Good thing our friend Sahit was there to help."

# the findall() function finds every instance of a specified word pattern within a text
re.findall(r'Samuel', text)
# Out:
# ['Samuel', 'Samuel']

# %% [markdown]
# Let's say that instead of only wanting to find Samuel, we wanted to find every word in the text starting with 'Sa'. What would we do? Use pattern matching!

# %%
re.findall(r'Sa[a-z]*', text)
# Out:
# ['Samuel', 'Samuel', 'Sahit']

# %% [markdown]
# You may be wondering what the [a-z] in the Sa[a-z] pattern means. This is called a **set** in regex. When characters are within a set, such as  [abcde], any one character will match. However, regex has a special rule where [a-z] means the same thing as [abcde...xyz].
#
# Here are some more:
# ~~~
# [0-9]        any numeric character
# [a-z]        any lowercase alphabetic character
# [A-Z]        any uppercase alphabetic character
# [aeiou]      any vowel (i.e. any character within the brackets)
# [0-9a-z]     to combine sets, list them one after another
# [^...]       exclude specific characters
# ~~~
#
#
# You still may be wondering how the entirety of Sahit was able to be matched if only one character within [a-z] would match. The answer is something called a **quantifier**!
#
# Rules:
# ~~~
# *        0 or more of the preceding character/expression
# +        1 or more of the preceding character/expression
# ?        0 or 1 of the preceding character/expression
# {n}      n copies of the preceding character/expression
# {n,m}    n to m copies of the preceding character/expression
# ~~~
#
# Say that now, you only wanted to return Samuel when the name was mentioned at the beginning of the text.

# %%
re.findall(r'^Samuel', text)
# Out:
# ['Samuel']

# %% [markdown]
# **Special characters**, such as the *^* which was just used in the pattern above, match strings that have a specific placement in a sentence. For example, *^* matches the subsequent pattern only if it is at the beginning of the string. This is why only a single 'Samuel' was returned.
#
# Rules:
# ~~~
# .         any single character except newline character
# ^         start of string
# $         end of entire string
# \n        new line
# \r        carriage return
# \t        tab
#
# ~~~

# %% [markdown]
# **Python RegEx Methods**
#
# * `re.findall(pattern, string)`: Returns all phrases that match your pattern in the string.
#
# * `re.sub(pattern, replacment, string)`: Return the string after replacing the leftmost non-overlapping occurences of the pattern in string with replacement
#
# * `re.split(pattern, string)`: Split string by the occurrences of pattern. If capturing parentheses are used in pattern, then the text of all groups in the pattern are also returned as part of the resulting list.

# %% [markdown]
# ## Part 4: Concordances and Collocation

# %% [markdown]
# ### 4.1 Concordance
# A concordance view shows us every occurrence of a given word, together with some context. Here we look up the word "petition" in casebody of the California Dataset by entering text followed by a period, then the term concordance, and then placing “petition” in parentheses.

# %%
import nltk
nltk.download('punkt')
from nltk.text import Text
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
case_body = df['casebody'][0]['data']['opinions'][0]['text']
case_body_tokenized = word_tokenize(case_body)
text = Text(case_body_tokenized)
text.concordance("petition")
# Out:
# Displaying 7 of 7 matches:
#  ) ) . The Department also filed a petition on Larry ’ s behalf to establish a
# same date , the Department filed a petition to establish an obligation on the
# Department to intervene and file a petition to establish child support on beha
# ze the Department to intervene and petition to establish child support on beha
# ver , pertain to the merits of the petition to establish a child support oblig
#  to intervene , the merits of that petition were never reached . The only issu
# nn ’ s unverified objection to the petition to intervene where she states that

# %% [markdown]
# **Question 6: write your own code to explore the occurence of the word *court***

# %%
...
# Out:
# Ellipsis

# %% [markdown]
# ### 4.2 Collocation
# Collocations are expressions of multiple words which commonly co-occur. For example, the top ten bigram collocations in casebody of California Dataset are listed below, as measured using Pointwise Mutual Information.

# %%
from nltk.collocations import *
bigram_measures = nltk.collocations.BigramAssocMeasures()
trigram_measures = nltk.collocations.TrigramAssocMeasures()
fourgram_measures = nltk.collocations.QuadgramAssocMeasures()

# %%
bigram_finder = BigramCollocationFinder.from_words(case_body_tokenized)
bigram_finder.nbest(bigram_measures.pmi, 10)
# Out:
# [('1.4', 'billion'),
#  ('256', 'U.S.'),
#  ('290', 'S.C.'),
#  ('351', 'S.E.2d'),
#  ('583', 'So'),
#  ('6th', 'Cir'),
#  ('923', 'F.2d'),
#  ('A.', 'McKay'),
#  ('ANALYSIS', 'Jurisdiction'),
#  ('America', 'Bank')]

# %% [markdown]
# **Question 7: Using the methods defined above, find the top 10 trigram and fourgram collocations.**

# %%
# Trigram
...

# %%
# FourGram
...

# %% [markdown]
# Congratulations! You have finished Lab 1!
